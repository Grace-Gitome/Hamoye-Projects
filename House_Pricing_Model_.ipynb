# %% [markdown]
# <a href="https://colab.research.google.com/github/Grace-Gitome/Hamoye-Projects/blob/main/House_Pricing_Model_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.style as style
# %matplotlib inline
style.use("fivethirtyeight")

from scipy.stats import norm
from scipy import stats

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import (LinearRegression,
                                  Ridge,
                                  Lasso)

from sklearn.metrics import (r2_score,
                             mean_absolute_error,
                             mean_squared_error)

# %%
#set the maximum number of rows/columns that can be displayed at once
pd.set_option ('max_columns',None)
pd.set_option ('max_rows',90)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-92f6892a-2564-4146-9da2-ecd6c3bae794" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-92f6892a-2564-4146-9da2-ecd6c3bae794">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
train  = pd.read_csv('train.csv') # 1 - 1460
test   = pd.read_csv('test.csv') 
sample = pd.read_csv('sample_submission.csv')

# %%
#check out how the final sample data is being presented
sample.head()
# Out:
#      Id      SalePrice
# 0  1461  169277.052498
# 1  1462  187758.393989
# 2  1463  183583.683570
# 3  1464  179317.477511
# 4  1465  150730.079977

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %% [markdown]
# ##**Preprocessing - combine train and test sets**

# %%
#strip off the target column ('SalesPrice') before concatetion, since it is null in the test data

target = train ['SalePrice']

# %%
#drop the ids from the train set, the test ids are useful for the sample submission

test_ids = test ['Id']

#train is the raw data, train1 is the data after the processing and dropping of columns
#salesprice can be dropped since it was already added to the target
train1 =train.drop(['Id', 'SalePrice'] ,axis =1)

#new test set
test1 = test.drop('Id', axis = 1)

# %%
data = pd.concat([train1, test1], axis = 0) #stack them together 
data
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1454         160       RM         21.0     1936   Pave   NaN      Reg
# 1455         160       RM         21.0     1894   Pave   NaN      Reg
# 1456          20       RL        160.0    20000   Pave   NaN      Reg
# 1457          85       RL         62.0    10441   Pave   NaN      Reg
# 1458          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
target #the sales price from the training dataset
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %% [markdown]
# ##**Cleaning**

# %%
data2 = data.copy() #create a copy

# %%
data2["MSSubClass"] # the datatype  needs to be changed to string
# Out:
# 0        60
# 1        20
# 2        60
# 3        70
# 4        60
#        ...
# 1454    160
# 1455    160
# 1456     20
# 1457     85
# 1458     60
# Name: MSSubClass, Length: 2919, dtype: int64

# %%
data2['MSSubClass'] = data2['MSSubClass'].astype(str)

# %% [markdown]
# ###**ensure proper data types**

# %%
#gives all the numeric columns
data.select_dtypes(np.number)
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 1454         160         21.0     1936            4            7       1970
# 1455         160         21.0     1894            4            5       1970
# 1456          20        160.0    20000            5            7       1960
# 1457          85         62.0    10441            5            5       1992
# 1458          60         74.0     9627            7            5       1993
#
# ...

# %% [markdown]
# Look for features that have been denoted as numeric but should be categorical.<br>
# Then set them to strings.<br>
# Example: MSSublass Identifies the type of dwelling in the sale

# %% [markdown]
# ### **Fill in the missing values**

# %% [markdown]
# **Categorical missing values**

# %%
data2.select_dtypes('object').loc [:, data2.isna().sum() >0 ].columns #check all rows and display columns with sum of null values greater than 1
# Out:
# Index(['MSZoning', 'Alley', 'Utilities', 'Exterior1st', 'Exterior2nd',
#        'MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinType2', 'Electrical', 'KitchenQual', 'Functional',
#        'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PoolQC', 'Fence', 'MiscFeature', 'SaleType'],
#       dtype='object')

# %%
# The mode is used to fill in missing values

#impute using constant value (where a missing value means something )
for column in [ 'Alley', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
               'FireplaceQu', 'GarageType','GarageFinish', 'GarageQual','GarageCond',
               'PoolQC','Fence', 'MiscFeature'
    
]:
  data2[column] =data2[column].fillna('None')
  

#impute using column mode
for column in [ 'MSZoning','Utilities','Exterior1st','Exterior2nd','MasVnrType',
               'Electrical', 'KitchenQual', 'Functional','SaleType'
                              
    
]:
  data2[column] =data2[column].fillna(data2[column].mode ()[0]) #set as 0 since the mode can return multiple values

# %%
data2.select_dtypes('object').isna().sum()
# Out:
# MSSubClass        0
# MSZoning          0
# Street            0
# Alley             0
# LotShape          0
# LandContour       0
# Utilities         0
# LotConfig         0
# LandSlope         0
# Neighborhood      0
# Condition1        0
# Condition2        0
# BldgType          0
# HouseStyle        0
# RoofStyle         0
# RoofMatl          0
# Exterior1st       0
# Exterior2nd       0
# MasVnrType        0
# ExterQual         0
# ExterCond         0
# Foundation        0
# BsmtQual          0
# BsmtCond          0
# BsmtExposure      0
# BsmtFinType1      0
# BsmtFinType2     80
# Heating           0
# HeatingQC         0
# CentralAir        0
# Electrical        0
# KitchenQual       0
# Functional        0
# FireplaceQu       0
# GarageType        0
# GarageFinish      0
# GarageQual        0
# GarageCond        0
# PavedDrive        0
# PoolQC            0
# Fence             0
# MiscFeature       0
# SaleType          0
# SaleCondition     0
# dtype: int64

# %% [markdown]
# **Numerical missing values**

# %%
data3 = data2.copy()

# %%
#Use knn imputation to replace missing values
from sklearn.neighbors import KNeighborsRegressor

# %%
data2.select_dtypes('number').isna().sum()
# Out:
# LotFrontage      486
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea        23
# BsmtFinSF1         1
# BsmtFinSF2         1
# BsmtUnfSF          1
# TotalBsmtSF        1
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       2
# BsmtHalfBath       2
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt      159
# GarageCars         1
# GarageArea         1
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# dtype: int64

# %%
 #columns with no missing values
data3.loc[:, data3.isna().sum() == 0]
# Out:
#      MSSubClass MSZoning  LotArea Street Alley LotShape LandContour Utilities  \
# 0            60       RL     8450   Pave  None      Reg         Lvl    AllPub
# 1            20       RL     9600   Pave  None      Reg         Lvl    AllPub
# 2            60       RL    11250   Pave  None      IR1         Lvl    AllPub
# 3            70       RL     9550   Pave  None      IR1         Lvl    AllPub
# 4            60       RL    14260   Pave  None      IR1         Lvl    AllPub
# ...         ...      ...      ...    ...   ...      ...         ...       ...
# 1454        160       RM     1936   Pave  None      Reg         Lvl    AllPub
# 1455        160       RM     1894   Pave  None      Reg         Lvl    AllPub
# 1456         20       RL    20000   Pave  None      Reg         Lvl    AllPub
# 1457         85       RL    10441   Pave  None      Reg         Lvl    AllPub
# 1458         60       RL     9627   Pave  None      Reg         Lvl    AllPub
#
# ...

# %%
data3.loc[data3['LotFrontage'].isna() == False, 'LotFrontage']
# Out:
# 0        65.0
# 1        80.0
# 2        68.0
# 3        60.0
# 4        84.0
#         ...
# 1454     21.0
# 1455     21.0
# 1456    160.0
# 1457     62.0
# 1458     74.0
# Name: LotFrontage, Length: 2433, dtype: float64

# %%
def knn_impute(df, na_target):
    df = df.copy()
    
    numeric_df = df.select_dtypes(np.number)
    non_na_columns = numeric_df.loc[: ,numeric_df.isna().sum() == 0].columns
    
    y_train = numeric_df.loc[numeric_df[na_target].isna() == False, na_target]
    X_train = numeric_df.loc[numeric_df[na_target].isna() == False, non_na_columns]
    X_test = numeric_df.loc[numeric_df[na_target].isna() == True, non_na_columns]
    
    knn = KNeighborsRegressor()
    knn.fit(X_train, y_train)
    
    y_pred = knn.predict(X_test)
    
    df.loc[df[na_target].isna() == True, na_target] = y_pred
    
    return df

# %%
#function call 
knn_impute (data3, 'LotFrontage')
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0            60       RL         65.0     8450   Pave  None      Reg
# 1            20       RL         80.0     9600   Pave  None      Reg
# 2            60       RL         68.0    11250   Pave  None      IR1
# 3            70       RL         60.0     9550   Pave  None      IR1
# 4            60       RL         84.0    14260   Pave  None      IR1
# ...         ...      ...          ...      ...    ...   ...      ...
# 1454        160       RM         21.0     1936   Pave  None      Reg
# 1455        160       RM         21.0     1894   Pave  None      Reg
# 1456         20       RL        160.0    20000   Pave  None      Reg
# 1457         85       RL         62.0    10441   Pave  None      Reg
# 1458         60       RL         74.0     9627   Pave  None      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
data3.columns[data3.isna().sum() > 0]
# Out:
# Index(['LotFrontage', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath',
#        'GarageYrBlt', 'GarageCars', 'GarageArea'],
#       dtype='object')
