# %% [markdown]
# <a href="https://colab.research.google.com/github/Grace-Gitome/Hamoye-Projects/blob/main/Stage_A_assesment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-764c5402-9770-49c0-a9a8-5ae0b1c5be2e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-764c5402-9770-49c0-a9a8-5ae0b1c5be2e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv',encoding = "latin-1")
df
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.groupby(["Area","Y2017"]).sum()
# Out:
#                    Area Code  Item Code  Element Code    Y2014    Y2015  \
# Area     Y2017
# Algeria  -81.0             8       5536         10144     60.0    -10.0
#          -47.0             8       5438         10144    312.0     70.0
#          -11.0             4       2563          5072    -29.0    -11.0
#          -6.0              4       2680          5072      1.0      4.0
#          -5.0             12       8257         15412    -24.0    -24.0
# ...                      ...        ...           ...      ...      ...
# Zimbabwe  1891.0         181       2901           664   1986.0   1912.0
#           2209.0         181       2905          5301   2013.0   1851.0
#           3101.0         724      10888         21624  15424.0  13392.0
#           3452.0         362       5444         10262   7570.0   7104.0
#           14237.0        181       2501           511  13587.0  13815.0
#
#                      Y2016    Y2018
# Area     Y2017
# ...

# %%
df.groupby(['Element']).sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
df.groupby(["Element"]).sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
array = ([[94,89,63],
          [93,92,48],
          [92,94,56]])

# %%
array [:1,1:]
array
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-32814e9b1e87> in <module>
# ----> 1 array [:1,1:]
#       2 array
#
# TypeError: list indices must be integers or slices, not tuple

# %%
df.groupby(['Y2017', 'Area']).sum()
# Out:
#                                        Area Code  Item Code  Element Code  \
# Y2017     Area
# -1582.0   Egypt                              118       5445         10144
# -1200.0   Mozambique                         144       2532          5072
# -1159.0   Mozambique                         144       2907          5072
# -865.0    United Republic of Tanzania        215       2913          5072
# -860.0    United Republic of Tanzania        215       2556          5072
# ...                                          ...        ...           ...
#  96443.0  Egypt                               59       2501           511
#  106400.0 Ethiopia                           238       2501           511
#  112625.0 Nigeria                            159       2907          5301
#  117702.0 Nigeria                            159       2907          5511
#  190873.0 Nigeria                            159       2501           511
#
# ...

# %%
my_tuppy = (1,2,5,8)
my_tuppy[2] =6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-87881531e03b> in <module>
#       1 my_tuppy = (1,2,5,8)
# ----> 2 my_tuppy[2] =6
#
# TypeError: 'tuple' object does not support item assignment

# %%
#unique countries
df.nunique()
# Out:
# Area Code         49
# Area              49
# Item Code        122
# Item             119
# Element Code      18
# Element           18
# Unit               5
# Y2014           4493
# Y2015           4520
# Y2016           4520
# Y2017           4537
# Y2018           4591
# dtype: int64

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
#allocate 8 to x
y = [(2,4),(7,8),(1,5,9)]
x =y[1][-1]
x
# Out:
# 8

# %%
df.groupby(["Y2015", "Y2018"]).sum()
# Out:
#                      Area Code  Item Code  Element Code     Y2014     Y2016  \
# Y2015     Y2018
# -3161.0   -296.0           202       2905          5072     439.0   -1499.0
# -2152.0   -597.0           202       2514          5072     626.0   -1324.0
# -1284.0    1898.0          276       2905          5072    4569.0    3266.0
# -907.0    -529.0           251       2905          5072     520.0    -506.0
# -887.0     163.0           276       2518          5072    3134.0    2432.0
# ...                        ...        ...           ...       ...       ...
#  92443.0   98424.0          59       2501           511   90425.0   94447.0
#  100835.0  109224.0        238       2501           511   98094.0  103603.0
#  110798.0  117038.0        159       2907          5301  108756.0  116483.0
#  111663.0  118172.0        159       2907          5511  109593.0  119330.0
#  181137.0  195875.0        159       2501           511  176405.0  185960.0
#
#                         Y2017
# ...

# %%
S =[["him","sell"],
    [90,28,43]]

S[0][1][1]
# Out:
# 'e'

# %%
len(df)
# Out:
# 60943

# %%
df.shape
# Out:
# (60943, 12)

# %%
df.groupby(["Element"]).sum()
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
lst = [[35,'Portugal',94],[33,'Argentina',93],[30,'Brazil',92]]
col =['Age','Nationality','Overall']

data = pd.DataFrame(lst,
                    columns = col,
                    index =[1,2,3])
data
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
data.iloc[2]
# Out:
# Age                30
# Nationality    Brazil
# Overall            92
# Name: 3, dtype: object

# %%
df.groupby(["Element","Element"]).sum()
# Out:
#                                                                                Area Code  \
# Element                                Element
# Domestic supply quantity               Domestic supply quantity                   708993
# Export Quantity                        Export Quantity                            599910
# Fat supply quantity (g/capita/day)     Fat supply quantity (g/capita/day)         675050
# Feed                                   Feed                                       176272
# Food                                   Food                                       663295
# Food supply (kcal/capita/day)          Food supply (kcal/capita/day)              674057
# Food supply quantity (kg/capita/yr)    Food supply quantity (kg/capita/yr)        658446
# Import Quantity                        Import Quantity                            688174
# Losses                                 Losses                                     274353
# ...

# %%
df.groupby(['Area',]).aggregate({'Y2014': 'sum',
                                 'Y2015': 'sum',
                                 'Y2016': 'sum',
                                 'Y2017': 'sum',
                             'Y2018': 'sum'})
# Out:
#                                   Y2014       Y2015       Y2016       Y2017  \
# Area
# Algeria                       313375.33   324058.40   326007.41   325644.27
# Angola                        208584.42   209565.67   214725.32   229159.57
# Benin                         118050.79   108181.13   117963.59   124771.22
# Botswana                       22339.92    23024.85    22970.65    22101.30
# Burkina Faso                  105051.33   102701.22   107702.27   101855.07
# Cabo Verde                     14576.94    14538.93    14569.40    14650.74
# Cameroon                      217630.28   225220.72   231714.36   232030.43
# Central African Republic       28739.02    28885.34    29454.54    29937.00
# Chad                           65940.17    65835.88    72673.76    71594.68
# Comoros                           32.00       41.34       54.91       59.84
# Congo                          38699.26    40255.51    40592.66    41181.68
# ...

# %%
df.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64
